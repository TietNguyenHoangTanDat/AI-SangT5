# %% [markdown]
# <a href="https://colab.research.google.com/github/TietNguyenHoangTanDat/AI-SangT5/blob/main/EXAM_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('text.txt',mode='r') as accounts:
  print(f'{"MSSV":<10}{"Name":<20}{"Score":>4}')
  for record in accounts:
    MSSV,Name,Score = record.split()
    print(f'{"MSSV":<10}{"Name":<20}{"Score":>4}')
# Out:
# MSSV      Name                Score
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-475ea1dfadd1> in <module>
#       2   print(f'{"MSSV":<10}{"Name":<20}{"Score":>4}')
#       3   for record in accounts:
# ----> 4     MSSV,Name,Score = record.split()
#       5     print(f'{"MSSV":<10}{"Name":<20}{"Score":>4}')
#
# ValueError: too many values to unpack (expected 3)

# %%
import pandas as pd
ulr = 'BangDiem.csv'
dataframe = pd.read_csv(ulr)
dataframe.head(20)
dataframe.shape
dataframe.describe()
# Out:
#                MSSV       Diem
# count  2.000000e+01  20.000000
# mean   2.014650e+07   8.012500
# std    5.916080e+00   1.740529
# min    2.014649e+07   4.500000
# 25%    2.014649e+07   6.937500
# 50%    2.014650e+07   8.500000
# 75%    2.014650e+07   9.312500
# max    2.014651e+07  10.000000

# %%
dataframe.shape
# Out:
# (20, 5)

# %%
dataframe.describe()
# Out:
#                MSSV       Diem
# count  2.000000e+01  20.000000
# mean   2.014650e+07   8.012500
# std    5.916080e+00   1.740529
# min    2.014649e+07   4.500000
# 25%    2.014649e+07   6.937500
# 50%    2.014650e+07   8.500000
# 75%    2.014650e+07   9.312500
# max    2.014651e+07  10.000000

# %%
dataframe.loc[0:4]
dataframe.loc[:4]
# Out:
#        MSSV                  Ho va ten Khoa Khoa.1   Diem
# 0  20146488  Tiet Nguyen Hoang Tan Dat  K20    CKM  10.00
# 1  20146489               Nguyen Van A  K21    CKM   9.00
# 2  20146490               Nguyen Van B  K20    CKD   8.25
# 3  20146491               Nguyen Van C  K18    CKM   7.00
# 4  20146492               Nguyen Van D  K22    CKD   9.50

# %%
frame = dataframe.set_index(dataframe['Ho va ten'])
frame.loc['Nguyen Bui G']
# Out:
# MSSV             20146495
# Ho va ten    Nguyen Bui G
# Khoa                  K21
# Khoa.1                  X
# Diem                 8.25
# Name: Nguyen Bui G, dtype: object

# %%
dataframe[dataframe['Khoa.1']=='CKM'].head(10)
# Out:
#         MSSV                  Ho va ten Khoa Khoa.1   Diem
# 0   20146488  Tiet Nguyen Hoang Tan Dat  K20    CKM  10.00
# 1   20146489               Nguyen Van A  K21    CKM   9.00
# 3   20146491               Nguyen Van C  K18    CKM   7.00
# 6   20146494             Nguyen Hoang F  K17    CKM   7.50
# 8   20146496              Nguyen Tuan H  K22    CKM   9.00
# 10  20146498                Nguyen Ho M  K22    CKM   9.75
# 11  20146499              Nguyen Nhut N  K20    CKM   6.75
# 13  20146501              Nguyen Nhut P  K22    CKM   4.50
# 14  20146502              Nguyen Nhut Q  K20    CKM   4.75
# 16  20146504              Nguyen Toan S  K19    CKM  10.00

# %%
dataframe[(dataframe['Khoa.1']=='CKM')&(dataframe['Khoa']=='K20')]
# Out:
#         MSSV                  Ho va ten Khoa Khoa.1   Diem
# 0   20146488  Tiet Nguyen Hoang Tan Dat  K20    CKM  10.00
# 11  20146499              Nguyen Nhut N  K20    CKM   6.75
# 14  20146502              Nguyen Nhut Q  K20    CKM   4.75
# 17  20146505             Nguyen Thanh T  K20    CKM   9.75

# %%
dataframe['Khoa'].min()
# Out:
# 'K17'

# %%
dataframe['Khoa.1'].value_counts()
# Out:
# CKM    11
# CKD     5
# X       4
# Name: Khoa.1, dtype: int64

# %%
dataframe['Khoa.1'].unique()
# Out:
# array(['CKM', 'CKD', 'X'], dtype=object)

# %%
dataframe['Diem'].count()
# Out:
# 20

# %%
dataframe['Diem'].sum()
# Out:
# 160.25

# %%
dataframe['Diem'].mean()
# Out:
# 8.0125

# %%
dataframe['Khoa'].max()
# Out:
# 'K22'

# %%
dataframe.drop('Khoa',axis = 1).head(20)
# Out:
#         MSSV                  Ho va ten Khoa.1   Diem
# 0   20146488  Tiet Nguyen Hoang Tan Dat    CKM  10.00
# 1   20146489               Nguyen Van A    CKM   9.00
# 2   20146490               Nguyen Van B    CKD   8.25
# 3   20146491               Nguyen Van C    CKM   7.00
# 4   20146492               Nguyen Van D    CKD   9.50
# 5   20146493               Nguyen Thi E    CKD   6.00
# 6   20146494             Nguyen Hoang F    CKM   7.50
# 7   20146495               Nguyen Bui G      X   8.25
# 8   20146496              Nguyen Tuan H    CKM   9.00
# 9   20146497              Nguyen Nhut L    CKD   8.75
# 10  20146498                Nguyen Ho M    CKM   9.75
# 11  20146499              Nguyen Nhut N    CKM   6.75
# 12  20146500              Nguyen Nhut O      X   5.50
# 13  20146501              Nguyen Nhut P    CKM   4.50
# 14  20146502              Nguyen Nhut Q    CKM   4.75
# 15  20146503              Nguyen Nhat R      X   7.75
# ...

# %%
dataframe.drop(['Khoa.1','Khoa'],axis = 1).head(20)
# Out:
#         MSSV                  Ho va ten   Diem
# 0   20146488  Tiet Nguyen Hoang Tan Dat  10.00
# 1   20146489               Nguyen Van A   9.00
# 2   20146490               Nguyen Van B   8.25
# 3   20146491               Nguyen Van C   7.00
# 4   20146492               Nguyen Van D   9.50
# 5   20146493               Nguyen Thi E   6.00
# 6   20146494             Nguyen Hoang F   7.50
# 7   20146495               Nguyen Bui G   8.25
# 8   20146496              Nguyen Tuan H   9.00
# 9   20146497              Nguyen Nhut L   8.75
# 10  20146498                Nguyen Ho M   9.75
# 11  20146499              Nguyen Nhut N   6.75
# 12  20146500              Nguyen Nhut O   5.50
# 13  20146501              Nguyen Nhut P   4.50
# 14  20146502              Nguyen Nhut Q   4.75
# 15  20146503              Nguyen Nhat R   7.75
# 16  20146504              Nguyen Toan S  10.00
# 17  20146505             Nguyen Thanh T   9.75
# 18  20146506               Nguyen Thi U   9.25
# ...

# %%
dataframe.drop(dataframe.columns[2:4],axis = 1).head(20)
# Out:
#         MSSV                  Ho va ten   Diem
# 0   20146488  Tiet Nguyen Hoang Tan Dat  10.00
# 1   20146489               Nguyen Van A   9.00
# 2   20146490               Nguyen Van B   8.25
# 3   20146491               Nguyen Van C   7.00
# 4   20146492               Nguyen Van D   9.50
# 5   20146493               Nguyen Thi E   6.00
# 6   20146494             Nguyen Hoang F   7.50
# 7   20146495               Nguyen Bui G   8.25
# 8   20146496              Nguyen Tuan H   9.00
# 9   20146497              Nguyen Nhut L   8.75
# 10  20146498                Nguyen Ho M   9.75
# 11  20146499              Nguyen Nhut N   6.75
# 12  20146500              Nguyen Nhut O   5.50
# 13  20146501              Nguyen Nhut P   4.50
# 14  20146502              Nguyen Nhut Q   4.75
# 15  20146503              Nguyen Nhat R   7.75
# 16  20146504              Nguyen Toan S  10.00
# 17  20146505             Nguyen Thanh T   9.75
# 18  20146506               Nguyen Thi U   9.25
# ...

# %%
dataframe.groupby(['CKM']).head(20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-4cec02a82e53> in <module>
# ----> 1 dataframe.groupby(['CKM']).head(20)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7629         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7630         # "Union[bool, NoDefault]"; expected "bool"
# -> 7631         return DataFrameGroupBy(
#    7632             obj=self,
#    7633             keys=by,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     887             from pandas.core.groupby.grouper import get_grouper
#     888
# ...

# %%
dataframe.groupby('Khoa').count()
# Out:
#       MSSV  Ho va ten  Khoa.1  Diem
# Khoa
# K17      1          1       1     1
# K18      1          1       1     1
# K19      3          3       3     3
# K20      6          6       6     6
# K21      4          4       4     4
# K22      5          5       5     5

# %%
dataframe.groupby(['Khoa.1','Khoa']).head(20)
# Out:
#         MSSV                  Ho va ten Khoa Khoa.1   Diem
# 0   20146488  Tiet Nguyen Hoang Tan Dat  K20    CKM  10.00
# 1   20146489               Nguyen Van A  K21    CKM   9.00
# 2   20146490               Nguyen Van B  K20    CKD   8.25
# 3   20146491               Nguyen Van C  K18    CKM   7.00
# 4   20146492               Nguyen Van D  K22    CKD   9.50
# 5   20146493               Nguyen Thi E  K20    CKD   6.00
# 6   20146494             Nguyen Hoang F  K17    CKM   7.50
# 7   20146495               Nguyen Bui G  K21      X   8.25
# 8   20146496              Nguyen Tuan H  K22    CKM   9.00
# 9   20146497              Nguyen Nhut L  K21    CKD   8.75
# 10  20146498                Nguyen Ho M  K22    CKM   9.75
# 11  20146499              Nguyen Nhut N  K20    CKM   6.75
# 12  20146500              Nguyen Nhut O  K19      X   5.50
# 13  20146501              Nguyen Nhut P  K22    CKM   4.50
# 14  20146502              Nguyen Nhut Q  K20    CKM   4.75
# ...

# %%
dataframe.drop()

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data = pd.read_csv(url,sep=',')
data.head(20)
# Out:
#     Year      City       Sport       Discipline  NOC                Event  \
# 0   1924  Chamonix     Skating   Figure skating  AUT           individual
# 1   1924  Chamonix     Skating   Figure skating  AUT           individual
# 2   1924  Chamonix     Skating   Figure skating  AUT                pairs
# 3   1924  Chamonix   Bobsleigh        Bobsleigh  BEL             four-man
# 4   1924  Chamonix  Ice Hockey       Ice Hockey  CAN           ice hockey
# 5   1924  Chamonix    Biathlon         Biathlon  FIN      military patrol
# 6   1924  Chamonix     Skating   Figure skating  FIN                pairs
# 7   1924  Chamonix     Skating    Speed skating  FIN               10000m
# 8   1924  Chamonix     Skating    Speed skating  FIN               10000m
# 9   1924  Chamonix     Skating    Speed skating  FIN                1500m
# 10  1924  Chamonix     Skating    Speed skating  FIN                5000m
# 11  1924  Chamonix     Skating    Speed skating  FIN                5000m
# ...

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data[(data['Year']>2003)&(data['Year']<2009)&(data['NOC']=='FIN')]
# Out:
#       Year   City       Sport       Discipline  NOC                 Event  \
# 2131  2006  Turin     Curling          Curling  FIN               curling
# 2132  2006  Turin  Ice Hockey       Ice Hockey  FIN            ice hockey
# 2133  2006  Turin      Skiing    Alpine Skiing  FIN          giant slalom
# 2134  2006  Turin      Skiing  Cross Country S  FIN           Team sprint
# 2135  2006  Turin      Skiing   Freestyle Ski.  FIN                moguls
# 2136  2006  Turin      Skiing  Nordic Combined  FIN                  Team
# 2137  2006  Turin      Skiing      Ski Jumping  FIN       K120 team (90m)
# 2138  2006  Turin      Skiing      Ski Jumping  FIN  K90 individual (70m)
# 2139  2006  Turin      Skiing        Snowboard  FIN             Half-pipe
#
#      Event gender   Medal
# 2131            M  Silver
# 2132            M  Silver
# 2133            W  Silver
# 2134            W  Bronze
# 2135            M  Silver
# 2136            M  Bronze
# 2137            M  Silver
# ...

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
A = data[(data['Year']>2003)&(data['Year']<2009)&(data['NOC']=='FIN')]
A.groupby('Medal').count()
# Out:
#         Year  City  Sport  Discipline  NOC  Event  Event gender
# Medal
# Bronze     3     3      3           3    3      3             3
# Silver     6     6      6           6    6      6             6

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
A = data[(data['Year']>2003)&(data['Year']<2009)&(data['NOC']=='FIN')]
A.groupby(['Sport','Medal']).count()
# Out:
#                    Year  City  Discipline  NOC  Event  Event gender
# Sport      Medal
# Curling    Silver     1     1           1    1      1             1
# Ice Hockey Silver     1     1           1    1      1             1
# Skiing     Bronze     3     3           3    3      3             3
#            Silver     4     4           4    4      4             4

# %%
with open('text.txt', mode='w') as accounts:
  accounts.write('20146488 Tiet Nguyen Hoang Tan Dat 8.0\n')
  accounts.write('20146489 Nguyen Van A 9.0\n')
  accounts.write('20146490 Nguyen Van B 9.0\n')
  accounts.write('20146491 Nguyen Van C 8.0\n')
  accounts.write('20146492 Nguyen Van D 8.0\n')
  accounts.write('20146493 Nguyen Van E 8.0\n')
  accounts.write('20146494 Nguyen Van F 9.0\n')
  accounts.write('20146495 Nguyen Van G 9.0\n')
  accounts.write('20146496 Nguyen Van H 9.0\n')
  accounts.write('20146497 Nguyen Van J 9.0\n')
  accounts.write('20146498 Nguyen Van I 8.0\n')
  accounts.write('20146499 Nguyen Van K 8.0\n')
  accounts.write('20146500 Nguyen Van L 8.0\n')
  accounts.write('20146501 Nguyen Van M 8.0\n')
  accounts.write('20146502 Nguyen Van N 8.0\n')
  accounts.write('20146503 Nguyen Van O 8.0\n')
  accounts.write('20146504 Nguyen Van P 8.0\n')
  accounts.write('20146505 Nguyen Van U 8.0\n')
  accounts.write('20146506 Nguyen Van R 8.0\n')
  accounts.write('20146507 Nguyen Van W 8.0\n')

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
with open('text.txt', mode='w') as accounts:
  print('20146488 Tiet Nguyen Hoang Tan Dat 8.0',file=accounts)
  print('20146489 Nguyen Van A 9.0',file=accounts)
  print('20146490 Nguyen Van B 9.0',file=accounts)
  print('20146491 Nguyen Van C 9.0',file=accounts)
  print('20146492 Nguyen Van D 9.0',file=accounts)
  print('20146493 Nguyen Van E 9.0',file=accounts)
  print('20146494 Nguyen Van F 9.0',file=accounts)
  print('20146495 Nguyen Van G 9.0',file=accounts)
  print('20146496 Nguyen Van H 9.0',file=accounts)
  print('20146497 Nguyen Van I 9.0',file=accounts)
  print('20146498 Nguyen Van J 9.0',file=accounts)

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab notebooks allow you to combine **executable code** and **rich text** in a single document, along with **images**, **HTML**, **LaTeX** and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To learn more, see [Overview of Colab](/notebooks/basic_features_overview.ipynb). To create a new Colab notebook you can use the File menu above, or use the following link: [create a new Colab notebook](http://colab.research.google.com#create=true).
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To learn more about the Jupyter project, see [jupyter.org](https://www.jupyter.org).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Data science
# </div>
#
# With Colab you can harness the full power of popular Python libraries to analyze and visualize data. The code cell below uses **numpy** to generate some random data, and uses **matplotlib** to visualize it. To edit the code, just click the cell and start editing.

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from Github and many other sources. To learn more about importing data, and how Colab can be used for data science, see the links below under [Working with Data](#working-with-data).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just [a few lines of code](https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb). Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including [GPUs and TPUs](#using-accelerated-hardware), regardless of the power of your machine. All you need is a browser.

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the [machine learning examples](#machine-learning-examples) below.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## More Resources
#
# ### Working with Notebooks in Colab
#
# </div>
#
# - [Overview of Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
# - <img src="/img/new.png" height="20px" align="left" hspace="4px" alt="New"></img>
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Working with Data
# </div>
#
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Machine Learning Crash Course
#
# <div>
#
# These are a few of the notebooks from Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Linear regression with tf.keras using synthetic data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# </div>
#
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow with TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# </div>
#
# - [NeMo Voice Swap](https://colab.research.google.com/github/NVIDIA/NeMo/blob/stable/tutorials/VoiceSwapSample.ipynb): Use Nvidia's NeMo conversational AI Toolkit to swap a voice in an audio fragment with a computer generated one.
#
# - [Retraining an Image Classifier](https://tensorflow.org/hub/tutorials/tf2_image_retraining): Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - [Text Classification](https://tensorflow.org/hub/tutorials/tf2_text_classification): Classify IMDB movie reviews as either *positive* or *negative*.
# - [Style Transfer](https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization): Use deep learning to transfer style between images.
# - [Multilingual Universal Sentence Encoder Q&A](https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa): Use a machine learning model to answer questions from the SQuAD dataset.
# - [Video Interpolation](https://tensorflow.org/hub/tutorials/tweening_conv3d): Predict what happened in a video between the first and the last frame.
