# %% [markdown]
# <a href="https://colab.research.google.com/github/TietNguyenHoangTanDat/AI-SangT5/blob/main/passenger_week7_BTVN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import linear_model
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


url_1 = 'passenger.csv'
data = pd.read_csv(url_1)
data.hist()
plt.show
sns.pairplot(data)
sns.heatmap(correlation, annot = True)
correlation = data.corr()
print(correlation)
data.plot(kind = 'scatter', x = 'Miles(X)', y = 'Dollars (Y)', figsize = (9,9), color = 'black')
model = linear_model.LinearRegression()
model.fit(X = pd.DataFrame(data['Miles(X)']), y = data['Dollars (Y)'])
print(model.intercept_)
print(model.coef_)
model.score(X = pd.DataFrame(data['Miles(X)']), y = data['Dollars (Y)'])
y_pred = model.predict(X = pd.DataFrame(data['Miles(X)']))
plt.plot(data['Miles(X)'], y_pred, color='blue')

model = linear_model.LinearRegression()
X = pd.DataFrame([data['Miles(X)'], data['Miles(X)']**2, data['Miles(X)']**3, data['Miles(X)']**4]).T
model.fit(X, y = data['Dollars (Y)'])
print('Intercept cua mo hinh:', model.intercept_)
print('Coeffient cua mo hinh:', model.coef_)
print('Do chinh xac cua mo hinh', model.score(X, y = data['Dollars (Y)']))

range_values = np.arange(1.5, 5.5, 0.1)
data.plot(kind='scatter', x='Miles(X)', y='Dollars (Y)', figsize=(9, 9), color='black', xlim=(0, 7))
predictor = pd.DataFrame([range_values, range_values**2, range_values**3, range_values**4]).T
y_pred = model.predict(X=predictor)
plt.plot(range_values, y_pred, color='blue')

import matplotlib.pyplot as plt
data.plot(kind='scatter',x='Miles(X)',y= 'Dollars (Y)', figsize=(9,9), color='black')
x = data['Miles(X)']
y = data['Dollars (Y)']
plt.plot(x,y,'r')
plt.xlabel('Miles(X)')
plt.ylabel('Dollars (Y)')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#              Passenger  Miles(X)  Dollars (Y)
# Passenger     1.000000 -0.067441     0.050511
# Miles(X)     -0.067441  1.000000     0.921729
# Dollars (Y)   0.050511  0.921729     1.000000
# 934.5366384552517
# [1.07802533]
# Intercept cua mo hinh: 4578.071200471596
# Coeffient cua mo hinh: [-4.43153501e+00  2.52587806e-03 -4.61148199e-07  2.97832852e-11]
# Do chinh xac cua mo hinh 0.9674434442156724
